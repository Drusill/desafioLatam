# %% [markdown]
# ![logo_academia.png](data:image/png;base64,...)

# %% [markdown]
# # <center><strong><font color="green">Guía de estudio - Variable aleatoria II</font></strong></center>
#
# Veremos a continuación algunos aspectos importantes de la preparación y limpieza de datos. Además, veremos tipos de gráficos con Seaborn. Algunos de ellos ya los hemos utilizado, pero profundizaremos un poco más en algunos comandos específicos.
# ## <font color='green'>Tabla de contenidos</font>
#
# 1. Preparación de datos
# 	- Etapas de la preparación de datos
# 2. Limpieza de datos
# 	- Valores faltantes o nulos
# 	- Datos duplicados
# 	- Transformación de datos
# 3. Análisis exploratorio de datos
# 	- Uso de estadísticas descriptivas y gráficos para entender la distribución de datos
# 	- Exploración de relaciones y correlaciones entre variables
# 4. Gráficos con Seaborn
# 	- Gráficos de línea
# 	- Gráfico de barra
# 	- Scatterplot
# 	- Histogramas
# 	- Swarmplot
# 	- Boxplot
# 	- Pairplot
# 	- Subplots
#
# <center>
#
# ![comencemos.png](data:image/png;base64,...)
#
# </center>
#
# <center> <font color='green'> <strong>¡Comencemos!</strong></font> </center>
#
#
# ## <strong><font color="green">Preparación de datos</font></strong>
# La preparación de datos es un paso crítico e indispensable en cualquier proceso de análisis de datos y visualización. En el mundo de los datos hay una regla muy conocida: el 80% del tiempo de un científico de datos se dedicó a preparar sus datos, y sólo el 20% a trabajar en ellos. La importancia de la preparación de los datos radica en varios aspectos:
#
# *  **Calidad de los resultados:** los datos limpios, completos y bien estructurados conducen a resultados más precisos y confiables en el análisis. Si los datos están sucios o contienen errores, es probable que los resultados sean inexactos y conduzcan a conclusiones erróneas.
#
# *  **Toma de decisiones informadas:** la preparación adecuada de datos permite a los analistas obtener una comprensión más profunda de ellos antes de realizar cualquier análisis o visualización. Esto ayuda a tomar decisiones informadas y fundamentadas en evidencia.
#
# *  **Eficiencia en el análisis:** al preparar los datos de manera adecuada, se reduce el tiempo necesario para realizar el análisis. La limpieza y transformación previa facilitan el proceso y permiten que los analistas se centren en la interpretación y el descubrimiento de patrones relevantes.
#
# *  **Asegurar consistencia:** la preparación de datos garantiza que los datos se presenten de manera coherente y homogénea. Esto es especialmente importante cuando se combinan datos de diferentes fuentes o cuando se trabaja en proyectos a largo plazo.
#
# *  **Compatibilidad con herramientas y algoritmos:** muchas herramientas y algoritmos requieren que los datos estén en un formato específico. La preparación adecuada asegura que los datos se ajusten a los requisitos de las herramientas y algoritmos seleccionados.
#
# *  **Identificación de errores y valores atípicos:** durante la preparación de datos, se pueden detectar y manejar valores atípicos, errores y datos inconsistentes. Esto es fundamental para evitar que estos problemas afecten negativamente el análisis y las conclusiones.
#
# *  **Facilitar la visualización:** los datos bien preparados son más fáciles de visualizar y comunicar de manera efectiva. Una vez que los datos están limpios y estructurados, se pueden crear gráficos y representaciones visuales que sean claras y comprensibles.
#
# *  **Minimizar sesgos y errores de interpretación:** la preparación de datos rigurosa y exhaustiva ayuda a minimizar el riesgo de sesgos y errores en la interpretación. Al abordar los problemas de calidad de datos, se asegura que el análisis sea más objetivo y confiable.
#
#
# ### <strong><font color="green">Etapas de la preparación de datos</font></strong>
#
# La preparación de datos considera una serie de procesos y tareas que se llevan a cabo para garantizar que estén limpios, completos y listos para su análisis o visualización. Los principales procesos incluidos en la preparación de datos son los siguientes:
#
# *  **Adquisición de datos:** este proceso involucra la recopilación de datos desde diversas fuentes, como bases de datos, archivos CSV, hojas de cálculo, APIs, fuentes web, sensores, entre otros.
#
# *  **Exploración de datos (EDA - Exploratory Data Analysis):** es una etapa inicial en la que se examinan los datos para comprender su estructura, características y distribución. Se utilizan técnicas descriptivas y gráficos para obtener información preliminar.
#
# *  **Limpieza de datos:** es el proceso de identificar y corregir errores, valores atípicos (outliers) y datos faltantes o nulos en el conjunto de datos. También puede implicar la estandarización de formatos y la corrección de inconsistencias.
#
# *  **Transformación de datos:** en esta etapa se realizan cambios en los datos para que estén en un formato adecuado para el análisis o la visualización. Esto puede incluir la normalización de variables, la codificación de datos categóricos y la agregación de información.
#
# * **Integración de datos:** cuando se trabaja con múltiples fuentes de datos, es necesario combinarlos de manera adecuada para crear un conjunto de datos coherente y completo.
#
# *  **Selección de características (feature selection):** en el análisis de datos, en ocasiones es necesario reducir la cantidad de características o variables a las más relevantes para el objetivo específico del análisis.
#
# *  **Reducción de dimensionalidad (dimensionality reduction):** si el conjunto de datos tiene muchas variables, esta etapa busca reducir la cantidad de dimensiones para facilitar el análisis y la visualización.
#
# *  **División de datos:** en muchos casos, se divide el conjunto de datos en conjuntos de entrenamiento y prueba para el desarrollo y validación de modelos de machine learning.
#
# *  **Creación de variables derivadas:** en algunos casos, es útil crear nuevas variables que sean combinaciones o transformaciones de las variables originales para obtener una perspectiva diferente.
#
# *  **Formateo de datos para visualización:** preparar los datos en el formato adecuado para que las herramientas de visualización puedan interpretarlos y generar gráficos o representaciones visuales.
#
# *  **Validación y verificación:** verificar que los datos preparados sean coherentes con las expectativas y que no haya errores en el proceso de preparación.
#
# *  **Documentación:** registrar y documentar los pasos realizados en la preparación de datos para asegurar la reproducibilidad y facilitar el trabajo futuro.
#
# Estos procesos no son necesariamente lineales, y en la práctica, pueden requerir iteraciones y ajustes a medida que se avanza en el análisis y se descubren nuevos desafíos en los datos.
#
# ## <strong><font color="green">Limpieza de datos</font></strong>
#
# La limpieza de datos es un proceso fundamental en el análisis de datos, que implica la identificación y corrección de problemas que puedan afectar la calidad y confiabilidad de los resultados. Entre los desafíos más comunes que se abordan durante la limpieza de datos se encuentran la identificación y manejo de valores atípicos, el tratamiento de valores faltantes o nulos, y la detección y resolución de duplicados.
#
# ### <strong><font color="green">Valores faltantes o nulos</font></strong>
#
# Los valores faltantes o nulos son aquellos campos de datos que no contienen información para ciertas observaciones. Estos valores pueden deberse a diversas razones, como errores en la recolección de datos, problemas técnicos o simplemente porque ciertas observaciones no tenían la información disponible.
#
# El tratamiento de valores faltantes es crítico, ya que muchos algoritmos y técnicas de análisis no pueden manejar estos valores. Hay varias opciones para abordarlos, como eliminar las observaciones con valores faltantes, imputar valores basados en estadísticas como la media o la mediana, o utilizar técnicas más avanzadas de imputación, como regresión o modelos de machine learning.
#
# Veremos esto con un ejemplo:

# %%
import pandas as pd
import numpy as np
from statistics import mode
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('loans_train.csv')
df.apply(lambda x: sum(x.isnull()), axis=0)
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# %%time
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB
# CPU times: user 3.74 ms, sys: 422 μs, total: 4.16 ms
# Wall time: 3.93 ms

# %%
df.shape
# Out:
# (614, 13)

# %% [markdown]
# Entre otras , la variable Credit_History muestra 50 valores nulos que debemos trabajar y corregir. Una opción es remplazar en el dataFrame los valores faltantes por el promedio de los valores no nulos.

# %%
df['LoanAmount'].fillna(df['LoanAmount'].mean(), inplace=True)
# Out:
# /var/folders/v4/7dd1ltfn517dxr1cpnssshx00000gn/T/ipykernel_28858/1977403596.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['LoanAmount'].fillna(df['LoanAmount'].mean(), inplace=True)

# %% [markdown]
# Otro aspecto que puede interesarnos es que los datos se encuentren correctamente formateados, para lo que podemos utilizar el método **unique** para que cuente, por columna, cuántos valores únicos hay. Por ejemplo:

# %%
df["Gender"].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64

# %%
df["Gender"].isna().sum()
# Out:
# 13

# %% [markdown]
# Vemos aquí que hay solo 3 opciones, una de las cuales es la falta de dato (nan). Podría haber ocurrido que en esta columna hubiera registros como "M", "F", o algún otro que necesitaríamos interpretar y reescribir si fuera necesario; este método nos cirve para advertirlo.

# %% [markdown]
# ### <strong><font color="green">Datos duplicados</font></strong>
#
# Los datos duplicados son observaciones que aparecen más de una vez en el conjunto de datos. Estos duplicados pueden surgir debido a errores en la recopilación o el ingreso de datos, y pueden distorsionar el análisis y las conclusiones.
#
# Para detectar duplicados, es necesario comparar las observaciones y buscar coincidencias exactas o casi exactas en todas las variables relevantes. Una vez identificados, los duplicados se pueden eliminar para garantizar que cada observación sea única y no afecte negativamente el análisis.
#
# Python nos ofrece el método **drop.duplicates**, cuya sintaxis es:
#
# <center>
# data_sin_duplicados = df.drop.duplicates(subset=[‘columna1’,’columna2’, ... ])
# </center>
#
#
# De esta manera, guardaremos en un nuevo dataFrame el original (**df**) sin los datos repetidos  **considerando las columnas indicadas**. Es decir, el método considerará un dato como duplicado si coinciden los datos correspondientes a las columnas especificadas, aunque no estén repetidos en las otras. Si no pondemos nada, el método considerará como dato repetido solo si la coincidencia es absoluta, es decir, en todas las columnas.
#
# Observa, además, que si aplicamos el método "directamente", es decir, sin guardar en otro dataFrame, el resultado se guardará en el dataFrame original, es decir, lo modificará.

# %%
df.drop_duplicates()
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.drop_duplicates().shape
# Out:
# (614, 13)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### <strong><font color="green">Transformación de datos</font></strong>
#
# Esta etapa implica aplicar técnicas para ajustar los datos a un formato adecuado que facilite su interpretación y análisis. Entre las transformaciones más comunes se encuentran la normalización y estandarización de datos, la discretización y binning de variables numéricas, y la codificación de variables categóricas.
#
#
# #### Normalización y estandarización de datos:
#
# La normalización y estandarización son técnicas que se utilizan para escalar los datos numéricos y colocarlos en una escala común.  Se trata de ajustar los valores para que estén en un rango específico, generalmente entre 0 y 1, lo que es útil cuando se trabaja con diferentes unidades o magnitudes. Por otro lado, la estandarización transforma los datos para que tengan una media de 0 y una desviación estándar de 1, lo que ayuda a eliminar sesgos y comparar variables con diferentes escalas.
#
# La normalización y estandarización son especialmente importantes cuando se utilizan algoritmos de machine learning que se basan en distancias o magnitudes, como el gradiente descendente o el algoritmo K-Nearest Neighbors (K-NN).
#
# #### Discretización y binarizar de variables numéricas
#
# Es el proceso de convertir variables numéricas en variables categóricas al agrupar los valores en rangos o intervalos. Esta técnica es útil cuando se quiere simplificar el análisis o cuando se tienen datos continuos que se pueden agrupar en categorías significativas.
#
# Por ejemplo, si se tiene una variable de edades, se puede discretizar en grupos como "jóvenes", "adultos" y "ancianos". El binning es una forma específica de discretización que divide el rango de valores en intervalos equitativos, lo que facilita la visualización y el análisis.
#
#
# #### Codificación de variables categóricas
#
# Las variables categóricas representan atributos con diferentes categorías o etiquetas, como género, tipo de producto o país. Los algoritmos de machine learning suelen requerir que los datos estén en formato numérico, por lo que es necesario codificar las variables categóricas en valores numéricos.
#
# Existen varias técnicas de codificación, como la codificación one-hot, donde se crea una columna binaria para cada categoría, o la codificación ordinal, que asigna valores numéricos a las categorías según un orden específico.
#
# La transformación de datos juega un papel fundamental en el análisis y modelado de datos, ya que ayuda a garantizar que los datos sean adecuados para su uso con diversas técnicas y algoritmos. Al aplicar técnicas de normalización, estandarización, discretización y codificación, los datos se vuelven más comprensibles y aptos para la generación de conocimientos significativos y la toma de decisiones informadas.
#
#
# ## <strong><font color="green">Análisis exploratorio de datos (EDA)</font></strong>
#
# El Análisis Exploratorio de Datos (EDA) es una fase crucial en cualquier proceso de análisis y visualización de datos. En esta etapa, los analistas utilizan una combinación de estadísticas descriptivas y gráficos para obtener una comprensión profunda de los datos y extraer información relevante. Dos aspectos fundamentales del EDA son el uso de estadísticas descriptivas y la exploración de relaciones y correlaciones entre variables.
#
# ### Uso de estadísticas descriptivas y gráficos para entender la distribución de datos
#
# Las estadísticas descriptivas son herramientas clave en el EDA que resumen y caracterizan los datos de manera concisa. Estas incluyen medidas como la media, mediana, moda, desviación estándar, mínimo, máximo y cuartiles. Estas estadísticas permiten entender la tendencia central, la dispersión y la forma de la distribución de los datos.
#
# Además de las estadísticas descriptivas, los gráficos desempeñan un papel crucial en el EDA, ya que permiten visualizar la distribución de los datos de manera más intuitiva. Algunos gráficos comunes en el EDA incluyen histogramas para visualizar la distribución de variables numéricas, gráficos de barras para representar frecuencias de variables categóricas, y gráficos de caja (boxplots) para mostrar estadísticas resumidas y detectar valores atípicos.
#
# ### Exploración de relaciones y correlaciones entre variables
#
# El análisis exploratorio de relaciones y correlaciones es una parte esencial del EDA. Consiste en examinar cómo se relacionan las variables entre sí y cómo influyen mutuamente en el conjunto de datos. Esto se puede lograr utilizando gráficos de dispersión (scatter plots) para visualizar la relación entre dos variables numéricas.
#
# Además, la correlación es una métrica que cuantifica la relación lineal entre dos variables numéricas. Un coeficiente de correlación cercano a 1 indica una correlación positiva fuerte, mientras que un valor cercano a -1 indica una correlación negativa fuerte. Una correlación cercana a 0 indica una relación débil o inexistente. Estos análisis permiten identificar patrones, tendencias y posibles dependencias entre variables, lo que puede ser fundamental para la toma de decisiones y la construcción de modelos predictivos.

# %% [markdown]
# # <center><strong><font color="green">Gráficos con pyhton - Seaborn</font></strong></center>
#
# Veremos a continuación algunos tipos de gráficos con Seaborn. Algunos de ellos ya los hemos utilizado, pero profundizaremos un poco más en algunos comandos específicos.
#
# ## <strong><font color="green">Páginas de ayda</font></strong>
#
# La creación de gráficos en Python requiere de muchos comandos que, la mayor parte de las veces, será muy difícil de memorizar. Tampoco es necesario hacerlo y, en ocasiones, bastarpa cn reutilizar ejemplos anteriores o plantillas prediseñadas. Puedes encontrar muchas de ellas en  [python graph gallery](https://python-graph-gallery.com/)
#
# La combinación de colores, y algunos criterios para su uso, pueden no resultar tan intuitivas o naturales si no tenemos competencias específicas de diseño gráfico. Buenas sugerencias de esto se úeden encontrar en [Adobe color](https://color.adobe.com/es/create/color-wheel)

# %% [markdown]
# ## <strong><font color="green">Graficos con Seaborn</font></strong>
#
# Hemos analizado en módulos anteriores la importancia de una visualización adecuada trabajar con datos. Veremos ahora como construir gráficos con Python, utilizando la biblioteca Seaborn. Para utilizarla, cargaremos primero las bibliotecas necesarias. Además, cargaremos la base de datos **tips** que viene incorporada en Seaborn, que incluye datos sobre comidas y propinas entregadas en un restaurante.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
tips = sns.load_dataset('tips')
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Las variables son:
#
# *  **total_bill:** El monto total de la cuenta, incluyendo el costo de la comida y las bebidas.
# * **tip:** La cantidad de propina dada por el cliente.
# * **sex:** El género del cliente (por ejemplo, 'Male' para hombres o 'Female' para mujeres).
# * **smoker:** Si el cliente fuma o no ('Yes' para sí o 'No' para no).
# * **day:** El día de la semana en que se realizó la visita al restaurante.
# *  **time:** El momento del día en que se realizó la visita ('Lunch' para almuerzo o 'Dinner' para cena).
# *  **size:** El tamaño del grupo de clientes que cenaron juntos.

# %% [markdown]
# ### <strong><font color="green">Gráfico de línea</font></strong>
#
# Vamos a graficar los consumos promedio por día en el restaurante. Para ello debemos primero escoger nuestros datos.

# %%
# Agrupar los datos por la columna 'day' y calcular el valor total promedio para cada día
promedio_por_dia = tips.groupby('day')['total_bill'].mean()
promedio_por_dia
# Out:
# /var/folders/v4/7dd1ltfn517dxr1cpnssshx00000gn/T/ipykernel_28858/1383948533.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   promedio_por_dia = tips.groupby('day')['total_bill'].mean()
# day
# Thur    17.682742
# Fri     17.151579
# Sat     20.441379
# Sun     21.410000
# Name: total_bill, dtype: float64

# %%
tips.shape
# Out:
# (244, 7)

# %% [markdown]
# Con esto, podemos graficar nuestros datos.

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#creamos un diccionario con los datos, y lo pasamos a un DataFrame

plt.figure(figsize=(8,6))  #configuramos el tamaño de la figura (8 x 6 pulgadas)
sns.lineplot(data=promedio_por_dia, marker='o', color='r'\
             , linestyle='-',markersize=6,label='Consumo promedio')
plt.xlabel('Días de la Semana')
plt.ylabel('Consumo promedio')
plt.title('Variación del gasto en comidas durante la Semana')
plt.legend()
# Mostrar el gráfico
plt.grid(True)  # Agregar cuadrícula de fondo (opcional)
plt.show()

# %% [markdown]
# #### Observaciones
#
# Hay parámetros que ya conoces, y otros que podemos precisar:
#
# * **marker:** Especifica el tipo de marcador para los puntos de datos en la gráfica de líneas. Algunas opciones comunes son:
#
#   *  '.': Punto
#   *  ',': Píxel
#   *  'o': Círculo
#   *  '^': Triángulo hacia arriba
#   *  'v': Triángulo hacia abajo
#   *  's': Cuadrado
#   *  '+': Cruz
#   *  '*': Estrella
#   *  'x': Cruz diagonal
#   *  'D': Diamante
#   *  'p': Pentágono
#
# * **color:** Especifica el color de la línea. Puedes usar nombres de colores comunes como 'b' para azul, 'r' para rojo, 'g' para verde, entre otros. También se pueden utilizar códigos hexadecimales para colores personalizados como '#FF5733'.
#
# *  **markersize:** Especifica el tamaño de los marcadores utilizados en la gráfica de líneas. Puedes proporcionar un valor numérico para establecer el tamaño deseado.

# %% [markdown]
# ### <strong><font color="green">Gráfico de barra</font></strong>

# %% [markdown]
# Veremos ahora qué ocurre con las propinas promedio dejadas por hombres y mujres. Para ello, agruparemos nuestros datos

# %%
propina_por_genero=tips.groupby('sex')['tip'].mean()
propina_por_genero
# Out:
# /var/folders/v4/7dd1ltfn517dxr1cpnssshx00000gn/T/ipykernel_28858/3068126999.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   propina_por_genero=tips.groupby('sex')['tip'].mean()
# sex
# Male      3.089618
# Female    2.833448
# Name: tip, dtype: float64

# %%
sns.set(style="whitegrid") #otras opciones: darkgrid, dark, white, ticks
plt.figure(figsize=(8, 6))
sns.barplot(x=propina_por_genero.index, y=propina_por_genero.values) #podemos acceder de esta manera a los datos
plt.xlabel('Género')
plt.ylabel('Propina promedio')
plt.title('Propina promedio por género')
custom_labels = ['Hombres', 'Mujeres']
plt.xticks(range(len(custom_labels)), custom_labels)
plt.show()

# %%
tips['sex'].value_counts()['Male']
# Out:
# 157

# %%
tips['sex'].value_counts('%')
# Out:
# sex
# Male      0.643443
# Female    0.356557
# Name: proportion, dtype: float64

# %%
tips.shape
# Out:
# (244, 7)

# %%
sns.barplot(x=['Male', 'Female'], y=[tips['sex'].value_counts()['Male']\
                                     ,tips['sex'].value_counts()['Female']])
# Out:
# <Axes: >

# %%
propina_por_genero.values
# Out:
# array([3.08961783, 2.83344828])

# %% [markdown]
# ### <strong><font color="green">Scatterplot</font></strong>
#
# Para construir este tipo de gráficos es preciso seleccionar dos conjuntos de variables, que representaremso como coordenadas. Seaborn nos permite, además, escoger alguna variable categórica para separarlas y distinguirlas por colores

# %%
sns.set(style='whitegrid')
sns.scatterplot(x='total_bill', y='tip', hue='time', data=tips, palette='Set2')
plt.xlabel('Consumo total')
plt.ylabel('Propina')
plt.title('Propina según consumo y día')
# Mostrar el gráfico
plt.show()

# %% [markdown]
# #### Observaciones
# *  Interpreta los parámetros utilizados.
#
# ### <strong><font color="green">Histogramas</font></strong>
#
# Seaborn nos ofrece dos funciones: **histplot** para una sola variable y crear un histograma simple, y **distplot** para más complejidad.

# %%
data=tips['total_bill']
sns.histplot(data, bins=10, color='skyblue') #observa variando el valor de bins, o simplemente no ponerlos
plt.title('Título')
plt.xlabel('Consumo total')
plt.ylabel('Frecuencia')
plt.axvline(tips['total_bill'].mean())
plt.show()

# %% [markdown]
# Ahora, utilizando **distplot** para crear dos gráficos en uno:

# %% [markdown]
# ¿Por qué usar distplot? Veremos que nos permite utilizar algunos otros parámetros y funcionalidades. Por ejemplo, podemos construir dos histogramas en uno separando por una variable categórica (en nuestro caso, 'time')

# %%
#creamos primero un objeto
ax = sns.displot(data=tips, x='total_bill', fill=True, kde=True) #  ,hue='time' )
#estamos señalando que, de los datos de "data", grafique los correspondientes a mean_perimeter distinguiendo por el valor de diagnosis

ax.set(xlabel='Consumo',ylabel='Frecuencia', title='Consumo por tipo de comida')
plt.axvline(tips['total_bill'].mean(), color='red')
plt.show()

# %% [markdown]
# ## <strong><font color="green">Swarmplot</font></strong>
#
# Swarmplot se utiliza para visualizar la distribución de puntos para cada categoría individual en un conjunto de datos categóricos.

# %%
sns.set(style='whitegrid')
sns.swarmplot(x='day', y='total_bill', data=tips)
plt.title('Swarm Plot - Total de la Cuenta por Día')
plt.xlabel('Día de la Semana')
plt.ylabel('Total de la Cuenta')
# Mostrar el gráfico
plt.show()

# %% [markdown]
# #### Observaciones
#
# En este ejemplo, utilizamos sns.swarmplot para crear un gráfico de dispersión (swarm plot) que muestra cómo se distribuye el total de la cuenta (total_bill) en función del día de la semana (day). Cada punto representa un valor individual del total de la cuenta y se agrupa verticalmente según el día correspondiente.

# %% [markdown]
# ## <strong><font color="green">Boxplot</font></strong>
#
# Son una herramienta gráfica utilizada para representar la distribución de un conjunto de datos numéricos y visualizar estadísticas descriptivas importantes. Estos gráficos proporcionan información sobre la mediana, los cuartiles, los valores atípicos y la dispersión de los datos.
#
# Los boxplots son especialmente útiles para:
# *  Identificar la simetría o sesgo en la distribución de los datos.
# *  Detectar valores atípicos o valores extremos.
# *  Comparar la distribución de varios conjuntos de datos.
# *  Visualizar la dispersión y concentración de los datos.

# %%
# Crear el boxplot para comparar el total de la cuenta (total_bill) según el día de la semana (day)
sns.boxplot(x='day', y='total_bill', data=tips)

# Personalización opcional
plt.title('Box Plot - Total de la Cuenta por Día')
plt.xlabel('Día de la Semana')
plt.ylabel('Total de la Cuenta')

# Mostrar el boxplot
plt.show()

# %%
sns.boxplot(y='total_bill', data=tips)
# Out:
# <Axes: ylabel='total_bill'>

# %% [markdown]
# #### Observaciones
#
# ¿Qué representan los puntos que aparecen más allá de las lineas finales?

# %% [markdown]
# ### <strong><font color="green">Pairplot</font></strong>
#
# Pairplot nos permite tener un "resumen gráfico" de las variables, agrupadas de a dos. No siempre todas las combinaciones tendrán sentido.

# %%
sns.pairplot(tips)

# %% [markdown]
# Podemos incluir parámetros, por ejemplo, para separar los gráficos por variables cualitativas

# %%
sns.pairplot(tips,hue='sex')
plt.show()

# %% [markdown]
# ## <strong><font color="green">Subplots</font></strong>
#
# Podemos, finalmente, crear una visualización con diferentes gráficos organizados en la forma que queramos, gracias a **subplots**

# %%
# Crear una figura con 3x2 subplots
fig, axes = plt.subplots(3, 2, figsize=(10, 13))

# Gráfico 1 - Scatter plot (total_bill vs. tip)
sns.scatterplot(x='total_bill', y='tip', data=tips, ax=axes[0, 0])
axes[0, 0].set_title('Scatter Plot - Total Bill vs. Tip')

# Gráfico 2 - Box plot (day vs. total_bill)
sns.boxplot(x='day', y='total_bill', data=tips, ax=axes[0, 1])
axes[0, 1].set_title('Box Plot - Total Bill por Día')

# Gráfico 3 - Bar plot (sex vs. total_bill)
sns.barplot(x='sex', y='total_bill', data=tips, ax=axes[1, 0])
axes[1, 0].set_title('Bar Plot - Total Bill por Género')

# Gráfico 4 - Violin plot (day vs. total_bill)
sns.swarmplot(x='day', y='total_bill', data=tips, ax=axes[1, 1])
axes[1, 1].set_title('Violin Plot - Total Bill por Día')

# Gráfico 5 - Count plot (day)
sns.countplot(x='day', data=tips, ax=axes[2, 0]) #analiza qué hace este gráfico
axes[2, 0].set_title('Count Plot - Día')

# Gráfico 6 - Histograma (total_bill)
sns.histplot(x='total_bill', data=tips, kde=True, ax=axes[2, 1])
axes[2, 1].set_title('Histograma - Total Bill')

# Ajustar el espaciado entre los subplots
plt.tight_layout()

# Mostrar los subplots
plt.show()

# %% [markdown]
# ## <strong><font color="green">Heatmap</font></strong>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_correlaciones = tips.drop(columns=['sex', 'smoker', 'day', 'time','size']).corr()
tips_correlaciones
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %%
umbral = 0.68
correlaciones_filtradas = tips_correlaciones[(tips_correlaciones >= umbral) | (tips_correlaciones <= (umbral * -1))]
correlaciones_filtradas
# Out:
#             total_bill  tip
# total_bill         1.0  NaN
# tip                NaN  1.0

# %%
sns.heatmap(tips_correlaciones, annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(correlaciones_filtradas, annot=True, color='lightblue')
# Out:
# <Axes: >

# %%
data = tips[tips['day'] == 'Fri']['total_bill']
data
# Out:
# 90     28.97
# 91     22.49
# 92      5.75
# 93     16.32
# 94     22.75
# 95     40.17
# 96     27.28
# 97     12.03
# 98     21.01
# 99     12.46
# 100    11.35
# 101    15.38
# 220    12.16
# 221    13.42
# 222     8.58
# 223    15.98
# 224    13.42
# 225    16.27
# 226    10.09
# Name: total_bill, dtype: float64

# %%
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
lower_bound
# Out:
# -2.387500000000003

# %%
upper_bound
# Out:
# 36.2325

# %%
data>upper_bound
# Out:
# 90     False
# 91     False
# 92     False
# 93     False
# 94     False
# 95      True
# 96     False
# 97     False
# 98     False
# 99     False
# 100    False
# 101    False
# 220    False
# 221    False
# 222    False
# 223    False
# 224    False
# 225    False
# 226    False
# Name: total_bill, dtype: bool

# %%
tips.iloc[95:96, :]
# Out:
#     total_bill   tip   sex smoker  day    time  size
# 95       40.17  4.73  Male    Yes  Fri  Dinner     4

# %%
(data<lower_bound).sum()
# Out:
# 0

# %% [markdown]
# # DESAFIO

# %% [markdown]
# **1. Carga los datos y genera un dataFrame que excluya las columnas correspondientes a la abreviatura del país, código de llamada, capital, código de moneda, ciudad más grande, lenguaje oficial, latitud y longitud. Considerando estos datos, realiza una inspección inicial sobre ellos, considerando gráficos. Concluye.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.listdir()
# Out:
# ['Breast_cancer_data.csv',
#  'g110_tutoria_daniel_20250925.ipynb',
#  'loans_train.csv',
#  'world-data-2023.csv',
#  '.ipynb_checkpoints']

# %%
df = pd.read_csv('world-data-2023.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 35 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    195 non-null    object
#  1   Density
# (P/Km2)                            195 non-null    object
#  2   Abbreviation                               188 non-null    object
#  3   Agricultural Land( %)                      188 non-null    object
#  4   Land Area(Km2)                             194 non-null    object
#  5   Armed Forces size                          171 non-null    object
#  6   Birth Rate                                 189 non-null    float64
#  7   Calling Code                               194 non-null    float64
#  8   Capital/Major City                         192 non-null    object
#  9   Co2-Emissions                              188 non-null    object
# ...

# %%
df.head()
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
# 3      Andorra              164           AD                40.00%
# 4       Angola               26           AO                47.50%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
# 3            468               NaN        7.20         376.0
# 4      1,246,700           117,000       40.73         244.0
#
#   Capital/Major City Co2-Emissions  ... Out of pocket health expenditure  \
# 0              Kabul         8,672  ...                           78.40%
# ...

# %%
columnas_a_eliminar = ['Abbreviation', 'Calling Code', 'Capital/Major City'
                       , 'Currency-Code', 'Largest city', 'Official language'
                       , 'Latitude', 'Longitude']

# %%
df.drop(columns=columnas_a_eliminar, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 27 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    195 non-null    object
#  1   Density
# (P/Km2)                            195 non-null    object
#  2   Agricultural Land( %)                      188 non-null    object
#  3   Land Area(Km2)                             194 non-null    object
#  4   Armed Forces size                          171 non-null    object
#  5   Birth Rate                                 189 non-null    float64
#  6   Co2-Emissions                              188 non-null    object
#  7   CPI                                        178 non-null    object
#  8   CPI Change (%)                             179 non-null    object
#  9   Fertility Rate                             188 non-null    float64
# ...

# %%
sns.pairplot(df)

# %%
df['Agricultural Land( %)'].unique()
# Out:
# array(['58.10%', '43.10%', '17.40%', '40.00%', '47.50%', '20.50%',
#        '54.30%', '58.90%', '48.20%', '32.40%', '57.70%', '1.40%',
#        '11.10%', '70.60%', '23.30%', '42.00%', '44.60%', '7.00%',
#        '33.30%', '13.60%', '34.80%', '45.60%', '33.90%', '2.70%',
#        '46.30%', '44.20%', '79.20%', '64.80%', '19.60%', '30.90%',
#        '20.60%', '6.90%', '8.20%', '39.70%', '21.20%', '56.20%', '40.30%',
#        '71.50%', '31.10%', '34.50%', '27.60%', '59.90%', '12.20%',
#        '45.20%', '11.60%', '62.00%', '73.40%', '48.70%', '22.20%',
#        '3.80%', '76.40%', '10.10%', '75.20%', '23.10%', nan, '36.30%',
#        '7.50%', '52.40%', '20.00%', '59.80%', '47.70%', '69.00%',
#        '47.60%', '23.50%', '36.00%', '59.00%', '58.00%', '8.60%',
#        '66.80%', '28.90%', '58.40%', '18.70%', '60.40%', '31.50%',
#        '28.20%', '21.40%', '64.50%', '24.60%', '43.20%', '41.00%',
#        '12.30%', '12.00%', '80.40%', '48.50%', '8.40%', '55.00%',
# ...

# %%
df['Agricultural Land( %)'].isna().sum()
# Out:
# 7

# %%
df['Porcentaje de tierra en decimales'] = df['Agricultural Land( %)'].str.replace('.', '')

# %%
df['Porcentaje de tierra en decimales'].unique()
# Out:
# array(['5810%', '4310%', '1740%', '4000%', '4750%', '2050%', '5430%',
#        '5890%', '4820%', '3240%', '5770%', '140%', '1110%', '7060%',
#        '2330%', '4200%', '4460%', '700%', '3330%', '1360%', '3480%',
#        '4560%', '3390%', '270%', '4630%', '4420%', '7920%', '6480%',
#        '1960%', '3090%', '2060%', '690%', '820%', '3970%', '2120%',
#        '5620%', '4030%', '7150%', '3110%', '3450%', '2760%', '5990%',
#        '1220%', '4520%', '1160%', '6200%', '7340%', '4870%', '2220%',
#        '380%', '7640%', '1010%', '7520%', '2310%', nan, '3630%', '750%',
#        '5240%', '2000%', '5980%', '4770%', '6900%', '4760%', '2350%',
#        '3600%', '5900%', '5800%', '860%', '6680%', '2890%', '5840%',
#        '1870%', '6040%', '3150%', '2820%', '2140%', '6450%', '2460%',
#        '4320%', '4100%', '1230%', '1200%', '8040%', '4850%', '840%',
#        '5500%', '1030%', '6430%', '7760%', '2800%', '870%', '3220%',
# ...

# %%
df['Porcentaje de tierra en decimales'] = np.where(df['Porcentaje de tierra en decimales'].isna()
         , df['Porcentaje de tierra en decimales']
         , '0.'+df['Porcentaje de tierra en decimales'])

# %%
df['Porcentaje de tierra en decimales'].unique()
# Out:
# array(['0.5810%', '0.4310%', '0.1740%', '0.4000%', '0.4750%', '0.2050%',
#        '0.5430%', '0.5890%', '0.4820%', '0.3240%', '0.5770%', '0.140%',
#        '0.1110%', '0.7060%', '0.2330%', '0.4200%', '0.4460%', '0.700%',
#        '0.3330%', '0.1360%', '0.3480%', '0.4560%', '0.3390%', '0.270%',
#        '0.4630%', '0.4420%', '0.7920%', '0.6480%', '0.1960%', '0.3090%',
#        '0.2060%', '0.690%', '0.820%', '0.3970%', '0.2120%', '0.5620%',
#        '0.4030%', '0.7150%', '0.3110%', '0.3450%', '0.2760%', '0.5990%',
#        '0.1220%', '0.4520%', '0.1160%', '0.6200%', '0.7340%', '0.4870%',
#        '0.2220%', '0.380%', '0.7640%', '0.1010%', '0.7520%', '0.2310%',
#        nan, '0.3630%', '0.750%', '0.5240%', '0.2000%', '0.5980%',
#        '0.4770%', '0.6900%', '0.4760%', '0.2350%', '0.3600%', '0.5900%',
#        '0.5800%', '0.860%', '0.6680%', '0.2890%', '0.5840%', '0.1870%',
#        '0.6040%', '0.3150%', '0.2820%', '0.2140%', '0.6450%', '0.2460%',
# ...

# %%
df['Porcentaje de tierra en decimales'] = df['Porcentaje de tierra en decimales'].str.replace('%', '',)

# %%
df['Porcentaje de tierra en decimales']
# Out:
# 0      0.5810
# 1      0.4310
# 2      0.1740
# 3      0.4000
# 4      0.4750
#         ...
# 190    0.2450
# 191    0.3930
# 192    0.4460
# 193    0.3210
# 194    0.4190
# Name: Porcentaje de tierra en decimales, Length: 195, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 28 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    195 non-null    object
#  1   Density
# (P/Km2)                            195 non-null    object
#  2   Agricultural Land( %)                      188 non-null    object
#  3   Land Area(Km2)                             194 non-null    object
#  4   Armed Forces size                          171 non-null    object
#  5   Birth Rate                                 189 non-null    float64
#  6   Co2-Emissions                              188 non-null    object
#  7   CPI                                        178 non-null    object
#  8   CPI Change (%)                             179 non-null    object
#  9   Fertility Rate                             188 non-null    float64
# ...

# %%
df['Porcentaje de tierra en decimales'] = pd.to_numeric(df['Porcentaje de tierra en decimales'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 28 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    195 non-null    object
#  1   Density
# (P/Km2)                            195 non-null    object
#  2   Agricultural Land( %)                      188 non-null    object
#  3   Land Area(Km2)                             194 non-null    object
#  4   Armed Forces size                          171 non-null    object
#  5   Birth Rate                                 189 non-null    float64
#  6   Co2-Emissions                              188 non-null    object
#  7   CPI                                        178 non-null    object
#  8   CPI Change (%)                             179 non-null    object
#  9   Fertility Rate                             188 non-null    float64
# ...

# %%
df.head()
# Out:
#        Country Density\n(P/Km2) Agricultural Land( %) Land Area(Km2)  \
# 0  Afghanistan               60                58.10%        652,230
# 1      Albania              105                43.10%         28,748
# 2      Algeria               18                17.40%      2,381,741
# 3      Andorra              164                40.00%            468
# 4       Angola               26                47.50%      1,246,700
#
#   Armed Forces size  Birth Rate Co2-Emissions     CPI CPI Change (%)  \
# 0           323,000       32.49         8,672   149.9          2.30%
# 1             9,000       11.78         4,536  119.05          1.40%
# 2           317,000       24.28       150,006  151.36          2.00%
# 3               NaN        7.20           469     NaN            NaN
# 4           117,000       40.73        34,693  261.73         17.10%
#
#    Fertility Rate  ... Minimum wage Out of pocket health expenditure  \
# ...

# %%
sns.pairplot(df)

# %%
df.columns
# Out:
# Index(['Country', 'Density\n(P/Km2)', 'Agricultural Land( %)',
#        'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Co2-Emissions',
#        'CPI', 'CPI Change (%)', 'Fertility Rate', 'Forested Area (%)',
#        'Gasoline Price', 'GDP', 'Gross primary education enrollment (%)',
#        'Gross tertiary education enrollment (%)', 'Infant mortality',
#        'Life expectancy', 'Maternal mortality ratio', 'Minimum wage',
#        'Out of pocket health expenditure', 'Physicians per thousand',
#        'Population', 'Population: Labor force participation (%)',
#        'Tax revenue (%)', 'Total tax rate', 'Unemployment rate',
#        'Urban_population', 'Porcentaje de tierra en decimales'],
#       dtype='object')

# %%
columnas_numericas = []
for columna in df.columns:
    if df[columna].dtype == 'float64':
        columnas_numericas.append(columna)
columnas_numericas
# Out:
# ['Birth Rate',
#  'Fertility Rate',
#  'Infant mortality',
#  'Life expectancy',
#  'Maternal mortality ratio',
#  'Physicians per thousand',
#  'Porcentaje de tierra en decimales']

# %%
# creamos nuestra matriz de gráficos
fig, axes = plt.subplots(len(columnas_numericas), len(columnas_numericas), figsize=(10, 13))
for i, columna1 in  enumerate(columnas_numericas):
    for j, columna2 in  enumerate(columnas_numericas):
        if columna1 == columna2:
            sns.histplot(df[columna1], bins=10, color='skyblue', ax=axes[i,j])
        else:
            sns.scatterplot(data=df, x=columna2, y=columna1, palette='Set2', ax=axes[i,j])
plt.tight_layout()
plt.show()
# Out:
# /var/folders/v4/7dd1ltfn517dxr1cpnssshx00000gn/T/ipykernel_28858/2065513017.py:8: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df, x=columna2, y=columna1, palette='Set2', ax=axes[i,j])
# /var/folders/v4/7dd1ltfn517dxr1cpnssshx00000gn/T/ipykernel_28858/2065513017.py:8: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df, x=columna2, y=columna1, palette='Set2', ax=axes[i,j])
# /var/folders/v4/7dd1ltfn517dxr1cpnssshx00000gn/T/ipykernel_28858/2065513017.py:8: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df, x=columna2, y=columna1, palette='Set2', ax=axes[i,j])
# /var/folders/v4/7dd1ltfn517dxr1cpnssshx00000gn/T/ipykernel_28858/2065513017.py:8: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df, x=columna2, y=columna1, palette='Set2', ax=axes[i,j])
# ...

# %%
columnas_numericas
# Out:
# ['Birth Rate',
#  'Fertility Rate',
#  'Infant mortality',
#  'Life expectancy',
#  'Maternal mortality ratio',
#  'Physicians per thousand',
#  'Porcentaje de tierra en decimales']

# %%
sns.scatterplot(data=df, x='Birth Rate', y='Fertility Rate')
# Out:
# <Axes: xlabel='Birth Rate', ylabel='Fertility Rate'>

# %%
# Crear el boxplot para comparar el total de la cuenta (total_bill) según el día de la semana (day)
sns.boxplot(y='Birth Rate', data=df)

# Personalización opcional
plt.title('Box Plot - Tasa de nacimiento')
plt.ylabel('Birth Rate')

# Mostrar el boxplot
plt.show()

# %%
# Crear el boxplot para comparar el total de la cuenta (total_bill) según el día de la semana (day)
sns.boxplot(y='Fertility Rate', data=df)

# Personalización opcional
plt.title('Box Plot - Tasa de fertilidad')
plt.ylabel('Fertility Rate')

# Mostrar el boxplot
plt.show()

# %%
df['Birth Rate'].isna().sum()
# Out:
# 6

# %%
df['Fertility Rate'].isna().sum()
# Out:
# 7

# %%
# obtenemos los faltantes en las 2 columnas
df[(df['Birth Rate'].isna()) | (df['Fertility Rate'].isna())]
# Out:
#                             Country Density\n(P/Km2) Agricultural Land( %)  \
# 56                         Eswatini               67                   NaN
# 73                     Vatican City            2,003                   NaN
# 113                          Monaco           26,337                   NaN
# 120                           Nauru              541                   NaN
# 128                 North Macedonia               83                   NaN
# 133  Palestinian National Authority              847                   NaN
# 181                          Tuvalu              393                60.00%
#
#     Land Area(Km2) Armed Forces size  Birth Rate Co2-Emissions  CPI  \
# 56          17,364               NaN         NaN           NaN  NaN
# 73               0               NaN         NaN           NaN  NaN
# 113              2               NaN         5.9           NaN  NaN
# 120             21               NaN         NaN           NaN  NaN
# ...

# %%
df[(df['Birth Rate'].isna() ==False) & (df['Fertility Rate'].isna() == False)]
# Out:
#          Country Density\n(P/Km2) Agricultural Land( %) Land Area(Km2)  \
# 0    Afghanistan               60                58.10%        652,230
# 1        Albania              105                43.10%         28,748
# 2        Algeria               18                17.40%      2,381,741
# 3        Andorra              164                40.00%            468
# 4         Angola               26                47.50%      1,246,700
# ..           ...              ...                   ...            ...
# 190    Venezuela               32                24.50%        912,050
# 191      Vietnam              314                39.30%        331,210
# 192        Yemen               56                44.60%        527,968
# 193       Zambia               25                32.10%        752,618
# 194     Zimbabwe               38                41.90%        390,757
#
#     Armed Forces size  Birth Rate Co2-Emissions       CPI CPI Change (%)  \
# ...

# %%
df.dropna(subset=['Birth Rate', 'Fertility Rate'])
# Out:
#          Country Density\n(P/Km2) Agricultural Land( %) Land Area(Km2)  \
# 0    Afghanistan               60                58.10%        652,230
# 1        Albania              105                43.10%         28,748
# 2        Algeria               18                17.40%      2,381,741
# 3        Andorra              164                40.00%            468
# 4         Angola               26                47.50%      1,246,700
# ..           ...              ...                   ...            ...
# 190    Venezuela               32                24.50%        912,050
# 191      Vietnam              314                39.30%        331,210
# 192        Yemen               56                44.60%        527,968
# 193       Zambia               25                32.10%        752,618
# 194     Zimbabwe               38                41.90%        390,757
#
#     Armed Forces size  Birth Rate Co2-Emissions       CPI CPI Change (%)  \
# ...

# %%
df = df.dropna(subset=['Birth Rate', 'Fertility Rate'])

# %%
df.shape
# Out:
# (188, 28)

# %%
sns.boxplot(y='Birth Rate', data=df)

# Personalización opcional
plt.title('Box Plot - Tasa de nacimiento')
plt.ylabel('Birth Rate')

# Mostrar el boxplot
plt.show()

# %%
sns.boxplot(y='Fertility Rate', data=df)

# Personalización opcional
plt.title('Box Plot - Tasa de fertilidad')
plt.ylabel('Fertility Rate')

# Mostrar el boxplot
plt.show()

# %%
df['Fertility Rate'].min()
# Out:
# 0.98

# %%
data = df['Fertility Rate']
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
print(f"Para Fertility Rate, los limites son: Inferior ==> {lower_bound}, Superior ==> {upper_bound}")
# Out:
# Para Fertility Rate, los limites son: Inferior ==> -1.13375, Superior ==> 6.43625

# %%
df[(df['Fertility Rate']< lower_bound) | (df['Fertility Rate']>upper_bound)]
# Out:
#     Country Density\n(P/Km2) Agricultural Land( %) Land Area(Km2)  \
# 125   Niger               19                36.10%      1,267,000
#
#     Armed Forces size  Birth Rate Co2-Emissions     CPI CPI Change (%)  \
# 125            10,000       46.08         2,017  109.32         -2.50%
#
#      Fertility Rate  ... Minimum wage Out of pocket health expenditure  \
# 125            6.91  ...       $0.29                            52.30%
#
#     Physicians per thousand  Population  \
# 125                    0.04  23,310,715
#
#     Population: Labor force participation (%)  Tax revenue (%)  \
# 125                                    72.00%           11.80%
#
#      Total tax rate  Unemployment rate Urban_population  \
# 125          47.20%              0.47%        3,850,231
#
#     Porcentaje de tierra en decimales
# 125                             0.361
#
# [1 rows x 28 columns]

# %%
df[(df['Fertility Rate']>= lower_bound) & (df['Fertility Rate']<=upper_bound)]
# Out:
#          Country Density\n(P/Km2) Agricultural Land( %) Land Area(Km2)  \
# 0    Afghanistan               60                58.10%        652,230
# 1        Albania              105                43.10%         28,748
# 2        Algeria               18                17.40%      2,381,741
# 3        Andorra              164                40.00%            468
# 4         Angola               26                47.50%      1,246,700
# ..           ...              ...                   ...            ...
# 190    Venezuela               32                24.50%        912,050
# 191      Vietnam              314                39.30%        331,210
# 192        Yemen               56                44.60%        527,968
# 193       Zambia               25                32.10%        752,618
# 194     Zimbabwe               38                41.90%        390,757
#
#     Armed Forces size  Birth Rate Co2-Emissions       CPI CPI Change (%)  \
# ...

# %%
df = df[(df['Fertility Rate']>= lower_bound) & (df['Fertility Rate']<=upper_bound)]

# %%
df.loc[124:126, :]
# Out:
#        Country Density\n(P/Km2) Agricultural Land( %) Land Area(Km2)  \
# 124  Nicaragua               55                42.10%        130,370
# 126    Nigeria              226                77.70%        923,768
#
#     Armed Forces size  Birth Rate Co2-Emissions     CPI CPI Change (%)  \
# 124            12,000       20.64         5,592  162.74          5.40%
# 126           215,000       37.91       120,369  267.51         11.40%
#
#      Fertility Rate  ... Minimum wage Out of pocket health expenditure  \
# 124            2.40  ...       $0.54                            36.00%
# 126            5.39  ...       $0.54                            72.20%
#
#     Physicians per thousand   Population  \
# 124                    0.98    6,545,502
# 126                    0.38  200,963,599
#
#     Population: Labor force participation (%)  Tax revenue (%)  \
# 124                                    66.40%           15.60%
# 126                                    52.90%            1.50%
#
# ...

# %%
sns.scatterplot(data=df, x='Birth Rate', y='Fertility Rate')
# Out:
# <Axes: xlabel='Birth Rate', ylabel='Fertility Rate'>

# %% [markdown]
# Se percibe un alta correlación entre estos dos atributos

# %%
df.loc[:, ['Birth Rate', 'Fertility Rate']].corr()
# Out:
#                 Birth Rate  Fertility Rate
# Birth Rate        1.000000        0.981516
# Fertility Rate    0.981516        1.000000

# %%
sns.heatmap(df.loc[:, ['Birth Rate', 'Fertility Rate']].corr(), annot=True)
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 187 entries, 0 to 194
# Data columns (total 28 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    187 non-null    object
#  1   Density
# (P/Km2)                            187 non-null    object
#  2   Agricultural Land( %)                      186 non-null    object
#  3   Land Area(Km2)                             187 non-null    object
#  4   Armed Forces size                          170 non-null    object
#  5   Birth Rate                                 187 non-null    float64
#  6   Co2-Emissions                              186 non-null    object
#  7   CPI                                        177 non-null    object
#  8   CPI Change (%)                             178 non-null    object
#  9   Fertility Rate                             187 non-null    float64
# ...

# %%
df.loc[:, ['Life expectancy', 'Physicians per thousand']].corr()
# Out:
#                          Life expectancy  Physicians per thousand
# Life expectancy                 1.000000                 0.701515
# Physicians per thousand         0.701515                 1.000000

# %%
sns.scatterplot(data=df, x='Life expectancy', y='Physicians per thousand')
# Out:
# <Axes: xlabel='Life expectancy', ylabel='Physicians per thousand'>

# %%
sns.heatmap(df.loc[:, ['Life expectancy', 'Physicians per thousand']].corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.boxplot(y='Life expectancy', data=df)

# Personalización opcional
plt.title('Box Plot - Expectativa de vida')
plt.ylabel('Life expectancy')

# Mostrar el boxplot
plt.show()

# %%
sns.boxplot(y='Physicians per thousand', data=df)

# Personalización opcional
plt.title('Box Plot - Médicos por cada 1000 personas')
plt.ylabel('Physicians per thousand')

# Mostrar el boxplot
plt.show()

# %%
data = df['Physicians per thousand']
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
print(f"Para Fertility Rate, los limites son: Inferior ==> {lower_bound}, Superior ==> {upper_bound}")
# Out:
# Para Fertility Rate, los limites son: Inferior ==> nan, Superior ==> nan

# %%
np.percentile(data, 75)
# Out:
# nan

# %%
194/4
# Out:
# 48.5

# %%
data[47:50]
# Out:
# 47    0.22
# 48    1.08
# 49    1.56
# Name: Physicians per thousand, dtype: float64

# %%
df['Physicians per thousand'].isna().sum()
# Out:
# 2

# %%
df[df['Physicians per thousand'].isna()]
# Out:
#            Country Density\n(P/Km2) Agricultural Land( %) Land Area(Km2)  \
# 98   Liechtenstein              238                32.20%            160
# 163    South Sudan               18                   NaN        644,329
#
#     Armed Forces size  Birth Rate Co2-Emissions       CPI CPI Change (%)  \
# 98                NaN        9.90            51       NaN            NaN
# 163           185,000       35.01         1,727  4,583.71        187.90%
#
#      Fertility Rate  ... Minimum wage Out of pocket health expenditure  \
# 98             1.44  ...          NaN                              NaN
# 163            4.70  ...          NaN                           61.30%
#
#     Physicians per thousand  Population  \
# 98                      NaN      38,019
# 163                     NaN  11,062,113
#
#     Population: Labor force participation (%)  Tax revenue (%)  \
# 98                                        NaN              NaN
# ...

# %%
datos = df[df['Physicians per thousand'].isna()==False]

# %%
datos.shape
# Out:
# (185, 28)

# %%
185/4
# Out:
# 46.25

# %%
data[44:50]
# Out:
# 44    4.12
# 45    0.07
# 46    4.01
# 47    0.22
# 48    1.08
# 49    1.56
# Name: Physicians per thousand, dtype: float64

# %%
datos.sort_values(by ='Physicians per thousand')['Physicians per thousand'].iloc[44:50]
# Out:
# 192    0.31
# 74     0.31
# 148    0.34
# 68     0.35
# 22     0.37
# 92     0.37
# Name: Physicians per thousand, dtype: float64

# %%
Q1 = 0.34

# %%
46.25*3
# Out:
# 138.75

# %%
data[134:139]
# Out:
# 141    2.49
# 142    2.98
# 143    4.01
# 144    0.13
# 145    2.52
# Name: Physicians per thousand, dtype: float64

# %%
datos.sort_values(by ='Physicians per thousand')['Physicians per thousand'].iloc[134:139]
# Out:
# 185    2.81
# 106    2.86
# 114    2.86
# 40     2.89
# 129    2.92
# Name: Physicians per thousand, dtype: float64

# %%
Q3 = 2.86

# %%
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
print(f"Para Physicians per thousand, los limites son: Inferior ==> {lower_bound}, Superior ==> {upper_bound}")
# Out:
# Para Fertility Rate, los limites son: Inferior ==> -3.4400000000000004, Superior ==> 6.640000000000001

# %%
Q3
# Out:
# 186

# %%
Q1
# Out:
# nan

# %%
df[(df['Physicians per thousand']< lower_bound) | (df['Physicians per thousand']>upper_bound)]
# Out:
#     Country Density\n(P/Km2) Agricultural Land( %) Land Area(Km2)  \
# 42     Cuba              106                59.90%        110,860
# 63  Georgia               57                34.50%         69,700
#
#    Armed Forces size  Birth Rate Co2-Emissions     CPI CPI Change (%)  \
# 42            76,000       10.17        28,284     NaN            NaN
# 63            26,000       13.47        10,128  133.61          4.90%
#
#     Fertility Rate  ... Minimum wage Out of pocket health expenditure  \
# 42            1.62  ...       $0.05                               NaN
# 63            2.06  ...       $0.05                            57.30%
#
#    Physicians per thousand  Population  \
# 42                    8.42  11,333,483
# 63                    7.12   3,720,382
#
#    Population: Labor force participation (%)  Tax revenue (%)  Total tax rate  \
# 42                                    53.60%              NaN             NaN
# ...

# %%
df['GDP'].unique()
# Out:
# array(['$19,101,353,833 ', '$15,278,077,447 ', '$169,988,236,398 ',
#        '$3,154,057,987 ', '$94,635,415,870 ', '$1,727,759,259 ',
#        '$449,663,446,954 ', '$13,672,802,158 ', '$1,392,680,589,329 ',
#        '$446,314,739,528 ', '$39,207,000,000 ', '$12,827,000,000 ',
#        '$38,574,069,149 ', '$302,571,254,131 ', '$5,209,000,000 ',
#        '$63,080,457,023 ', '$529,606,710,418 ', '$1,879,613,600 ',
#        '$14,390,709,095 ', '$2,446,674,101 ', '$40,895,322,865 ',
#        '$20,047,848,435 ', '$18,340,510,789 ', '$1,839,758,040,766 ',
#        '$13,469,422,941 ', '$86,000,000,000 ', '$15,745,810,235 ',
#        '$3,012,334,882 ', '$58,792,205,642 ', '$1,981,845,741 ',
#        '$27,089,389,787 ', '$38,760,467,033 ', '$1,736,425,629,520 ',
#        '$2,220,307,369 ', '$11,314,951,343 ', '$282,318,159,745 ',
#        '$19,910,000,000,000 ', '$323,802,808,108 ', '$1,185,728,677 ',
#        '$10,820,591,131 ', '$61,773,944,174 ', '$60,415,553,039 ',
# ...

# %%
df['GDP'].str.strip().str.replace(',','').str.replace('$','')
# Out:
# 0       19101353833
# 1       15278077447
# 2      169988236398
# 3        3154057987
# 4       94635415870
#            ...
# 190    482359318768
# 191    261921244843
# 192     26914402224
# 193     23064722446
# 194     21440758800
# Name: GDP, Length: 187, dtype: object

# %%
df['PGD_corregido'] = df['GDP'].str.strip().str.replace(',','').str.replace('$','')

# %%
df['PGD_corregido'] = pd.to_numeric(df['PGD_corregido'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 187 entries, 0 to 194
# Data columns (total 29 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    187 non-null    object
#  1   Density
# (P/Km2)                            187 non-null    object
#  2   Agricultural Land( %)                      186 non-null    object
#  3   Land Area(Km2)                             187 non-null    object
#  4   Armed Forces size                          170 non-null    object
#  5   Birth Rate                                 187 non-null    float64
#  6   Co2-Emissions                              186 non-null    object
#  7   CPI                                        177 non-null    object
#  8   CPI Change (%)                             178 non-null    object
#  9   Fertility Rate                             187 non-null    float64
# ...

# %%
df['PGD_corregido']
# Out:
# 0       19101353833
# 1       15278077447
# 2      169988236398
# 3        3154057987
# 4       94635415870
#            ...
# 190    482359318768
# 191    261921244843
# 192     26914402224
# 193     23064722446
# 194     21440758800
# Name: PGD_corregido, Length: 187, dtype: int64

# %%
df['Population'].unique()
# Out:
# array(['38,041,754', '2,854,191', '43,053,054', '77,142', '31,825,295',
#        '97,118', '44,938,712', '2,957,731', '25,766,605', '8,877,067',
#        '10,023,318', '389,482', '1,501,635', '167,310,838', '287,025',
#        '9,466,856', '11,484,055', '390,353', '11,801,151', '727,145',
#        '11,513,100', '3,301,000', '2,346,179', '212,559,417', '433,285',
#        '6,975,761', '20,321,378', '11,530,580', '25,716,544', '483,628',
#        '16,486,542', '25,876,380', '36,991,981', '4,745,185',
#        '15,946,876', '18,952,038', '1,397,715,000', '50,339,443',
#        '850,886', '5,380,508', '5,047,561', '4,067,500', '11,333,483',
#        '1,198,575', '10,669,709', '86,790,567', '5,818,553', '973,560',
#        '71,808', '10,738,958', '17,373,662', '100,388,073', '6,453,553',
#        '1,355,986', '6,333,135', '1,331,824', '112,078,730', '889,953',
#        '5,520,314', '67,059,887', '2,172,579', '2,347,706', '3,720,382',
# ...
